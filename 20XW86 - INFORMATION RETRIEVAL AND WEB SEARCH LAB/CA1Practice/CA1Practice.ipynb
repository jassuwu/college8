# %%
import numpy as np
import pandas as pd
import re
import collections

# %%
# Read the documents
docDB = []
docs_names = ['doc1.txt', 'doc2.txt', 'doc3.txt']
for name in docs_names:
    with open(f'./docs/{name}', 'r') as f:
        docDB.append(f.read())
docDB
# Out:
# ['THE ALLIES AFTER NASSAU IN DECEMBER 1960, THE U.S . FIRST\n\nPROPOSED TO HELP NATO DEVELOP ITS OWN NUCLEAR STRIKE FORCE . BUT EUROPE\n\nMADE NO ATTEMPT TO DEVISE A PLAN . LAST WEEK, AS THEY STUDIED THE\n\nNASSAU ACCORD BETWEEN PRESIDENT KENNEDY AND PRIME MINISTER MACMILLAN,\n\nEUROPEANS SAW EMERGING THE FIRST OUTLINES OF THE NUCLEAR NATO THAT THE\n\nU.S . WANTS AND WILL SUPPORT . IT ALL SPRANG FROM THE ANGLO-U.S .\n\nCRISIS OVER CANCELLATION OF THE BUG-RIDDEN SKYBOLT MISSILE, AND THE\n\nU.S . OFFER TO SUPPLY BRITAIN AND FRANCE WITH THE PROVED POLARIS (TIME,\n\nDEC . 28) . THE ONE ALLIED LEADER WHO UNRESERVEDLY WELCOMED THE POLARIS\n\nOFFER WAS HAROLD MACMILLAN, WHO BY THUS KEEPING A SEPARATE NUCLEAR\n\nDETERRENT FOR BRITAIN HAD SAVED HIS OWN NECK . BACK FROM NASSAU, THE\n\nPRIME MINISTER BEAMED THAT BRITAIN NOW HAD A WEAPON THAT " WILL LAST A\n\nGENERATION . THE TERMS ARE VERY GOOD . " MANY OTHER BRITONS WERE NOT SO\n\nSURE . THOUGH THE GOVERNMENT WILL SHOULDER NONE OF THE $800 MILLION\n\nDEVELOPMENT COST OF POLARIS, IT HAS ALREADY POURED $28 MILLION INTO\n\nSKYBOLT AND WILL HAVE TO SPEND PERHAPS $1 BILLION MORE FOR A FLEET OF\n\nMISSILE-PACKING SUBMARINES . AT BEST, THE BRITISH WILL NOT BE ABLE TO\n\nDESIGN, BUILD AND PROVE ITS NUCLEAR FLEET BEFORE 1970, THREE YEARS\n\nAFTER BRITAIN\'S BOMBER FORCE HAS PRESUMABLY BECOME OBSOLETE . THEN WHAT\n\n? TORY BACKBENCHERS ARE LOUDLY SKEPTICAL OF WHAT THEY CALL " THE\n\nSMALL TYPE " IN THE NASSAU PACT, WHICH STIPULATES THAT BRITAIN\'S\n\nPOLARIS SUBMARINE FLEET, EXCEPT WHEN " SUPREME NATIONAL INTERESTS "\n\nINTERVENE, MUST BE COMMITTED TO A TRULY MULTILATERAL NATO FORCE . DOES\n\nTHAT MEAN THAT BRITAIN WILL EVENTUALLY HAVE NO STRIKE FORCE OF ITS OWN\n\n? WHO WILL DECIDE WHEN OR WHETHER NATIONAL INTERESTS JUSTIFY\n\nWITHDRAWAL OF SUBMARINES FROM NATO, PARTICULARLY IF THOSE NATIONAL\n\nINTERESTS CONFLICT WITH U.S . POLICY ? THE BIGGEST QUESTION OF ALL IS\n\nWHETHER FRANCE\'S INCLUSION IN THE OFFER WAS A DELIBERATE PLOY BY JACK\n\nKENNEDY
ARATIONS IN WEIDNER\'S GARAGE . FIRST WEIDNER AND WAGNER\n\nATTACHED A HEAVY SNOWPLOW TO THE FRONT OF THE BUS, NOT TO PLOW SNOW,\n\nBUT TO SCOOP AWAY THE HEAVY OBSTACLES THEY KNEW AWAITED THEM AT\n\nROADBLOCKS AHEAD . TO ALL SIX LUGS ON EACH FRONT WHEEL THEY BOLTED\n\nSHARP BLADES OF THE TOUGHEST STEEL, AFFIXED SO THAT THE WHIRLING EDGES\n\nWOULD CHOP BARBED WIRE TO BITS . THEN THEY WEDGED ONE-QUARTER-INCH\n\nSECTIONS OF STEEL PLATE INSIDE THE BUS TO STOP BULLETS . AT LAST ALL\n\nWAS READY . ON CHRISTMAS EVE, WEIDNER AND WAGNER PILED THEIR WIVES AND\n\nFOUR CHILDREN ABOARD, NOT FORGETTING THREE TONS OF HOUSEHOLD BELONGINGS\n\n. FOR ADDED PROTECTION THE PLOTTERS SHOVELED A TON OF COAL AND POTATOES\n\nINTO THE BACK OF THE BUS . THEN THEY CHUGGED OFF NORTH TOWARD BERLIN\n\nALONG BACK ROADS TO ESCAPE COMMUNIST PATROLS . JUST BEFORE THEY REACHED\n\nTHE WALL, THEY PLANNED TO SWING WEST IN ORDER TO ENTER THE EAST-WEST\n\nAUTOBAHN LEADING TO THE U.S . SECTOR OF THE CITY . EN ROUTE, THE\n\nRADIATOR FROZE IN THE SUBZERO WEATHER . THAT FIXED, THEY WERE ONLY A\n\nFEW MILES FARTHER WHEN A TIRE BLEW OUT . THE KIDS WERE CRYING AND THE\n\nWIVES SHIVERING WITH COLD AND PANIC WHEN, AT LAST, THEY ARRIVED AT\n\nDREWITZ, THE MOST HEAVILY GUARDED CHECKPOINT ON THE ENTIRE AUTOBAHN TO\n\nBERLIN . IT WAS NO TIME TO STOP AND RECONSIDER . FLYING POTATOES . "\n\nWAH-AH, WAH-AH, " SHRIEKED THE POLICE-TYPE KLAXONS THAT WEIDNER HAD\n\nTHOUGHTFULLY INSTALLED IN ADVANCE . THE COMMUNIST GUARDS OBEDIENTLY\n\nRAISED THE FIRST OF THREE BARRIERS . BUT WHAT WAS A BUS DOING ON\n\nEMERGENCY DUTY ? SUDDENLY THE SHOOTING BEGAN TOO LATE . WAGNER, AT 40\n\nM.P.H., WAS ALREADY CRASHING THROUGH THE SECOND BARRIER 100 YARDS\n\nAHEAD, THEN THE THIRD, ONLY 20 YARDS AWAY . ITS WINDSHIELD SMASHED, ITS\n\nPASSENGERS SHAKEN, ITS CARGO OF COAL AND POTATOES IN EVERY CORNER OF\n\nTHE CAB, THE OLD BUS FINALLY LURCHED TO A STOP A FEW MILES DOWN THE\n\nROAD WHERE THE COMMUNISTS NO LONGER MATTERED AT THE U.S . CHECKPOINT, A\n\nFOOT OR TWO INSIDE WEST BERLIN .']

# %%
# Read the queries
with open('./docs/queries.txt', 'r') as f:
    content = f.read()
    matches = re.findall(r'\*QUERY\n\n(.+?)(\n\n)?(?=\*QUERY|$)', content, re.DOTALL)
queriesDB = [query[0] for query in matches]
queriesDB
# Out:
# ['THE ALLIES IN NASSAU',
#  'KHRUSHCHEV AND\n\nRUSSIA',
#  'BERLIN ONE LAST RUN HANS WEIDNER HAD BEEN HOPING FOR MONTHS TO\n\nESCAPE DRAB EAST GERMANY AND MAKE HIS WAY TO THE WEST']

# %%
# Read the stop words
with open('./docs/stop.txt', 'r') as f:
    content = f.read()
    matches = re.findall(r'^[A-Z0-9]+$', content, re.MULTILINE)
stopWordsDB = [word.lower() for word in matches]
stopWordsDB
# Out:
# ['a',
#  'about',
#  'above',
#  'across',
#  'actually',
#  'add',
#  'added',
#  'after',
#  'again',
#  'against',
#  'ago',
#  'all',
#  'almost',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyone',
#  'are',
#  'around',
#  'as',
#  'asked',
#  'at',
#  'b',
#  'back',
#  'bad',
#  'be',
#  'became',
#  'because',
#  'become',
#  'been',
#  'before',
#  'began',
#  'behind',
#  'being',
#  'best',
#  'better',
#  'between',
#  'big',
#  'biggest',
#  'both',
#  'brought',
#  'but',
#  'by',
#  'c',
#  'called',
#  'came',
#  'can',
#  'cannot',
#  'cent',
#  'come',
#  'complete',
#  'continued',
#  'could',
#  'd',
#  'day',
#  'decided',
#  'declared',
#  'despite',
#  'did',
#  'do',
#  'does',
#  'down',
#  'during',
#  'e',
#  'each',
#  'early',
#  'eight',
#  'enough',
#  'entire',
#  'ep',
#  'etc',
#  'even',
#  'ever',
#  'every',
#  'everything',
#  'f',
#  'face',
#  'faced',
#  'fact',
#  'failed',
#  'far',
#  'fell',
#  'few',
#  'finally',
#  'find',
#  'first',
#  'five',
#  'for',
#  'found',
#  'four',
#  'from',
#  'g',
#  'gave',
#  'get',
#  'give',
#  'given',
#  'go',
#  'going',
#  'good',
#  'got',
#  'h',
#  'had',
#  'has',
#  'have',
#  'having',
#  'he',
#  'held',
#  'her',
#  'here',
#  'him',
#  'himself',
#  'his',
#  'hour',
#  'hours',
#  'how',
#  'however',
#  'i',
#  'idea',
#  'if',
#  'in',
#  'including',
#  'instead',
#  'into',
#  'is',
#  'it',
#  'its',
#  'itself',
#  'j',
#  'k',
#  'keep',
#  'know',
#  'known',
#  'knows',
#  'l',
#  'lack',
#  'last',
#  'later',
#  'least',
#  'led',
#  'less',
#  'let',
#  'like',
#  'little',
#  'long',
#  'longer',
#  'look',
#  'lot',
#  'm',
#  'made',
#  'make',
#  'making',
#  'man',
#  'many',
#  'matter',
#  'may',
#  'me',
#  'means',
#  'men',
#  'might',
#  'miles',
#  'million',
#  'moment',
#  'month',
#  'months',
#  'more',
#  'morning',
#  'most',
#  'much',
#  'must',
#  'my',
#  'n',
#  'named',
#  'near',
#  'nearly',
#  'necessary',
#  'need',
#  'needed',
#  'needs',
#  'never',
#  'night',
#  'no',
#  'nor',
#  'not',
#  'note',
#  'nothing',
#  'now',
#  'o',
#  'of',
#  'off',
#  'often',
#  'on',
#  'once',
#  'one',
#  'only',
#  'or',
#  'other',
#  'others',
#  'our',
#  'out',
#  'outside',
#  'over',
#  'own',
#  'p',
#  'page',
#  'part',
#  'past',
#  'per',
#  'perhaps',
#  'place',
#  'point',
#  'proved',
#  'put',
#  'q',
#  'qm',
#  'question',
#  'r',
#  'really',
#  'recent',
#  'recently',
#  'reported',
#  'round',
#  's',
#  'said',
#  'same',
#  'say',
#  'says',
#  'sec',
#  'second',
#  'section',
#  'see',
#  'seemed',
#  'seems',
#  'sense',
#  'set',
#  'sets',
#  'seven',
#  'she',
#  'short',
#  'should',
#  'showed',
#  'since',
#  'single',
#  'six',
#  'small',
#  'so',
#  'some',
#  'soon',
#  'start',
#  'started',
#  'still',
#  'such',
#  't',
#  'take',
#  'taken',
#  'takes',
#  'ten',
#  'text',
#  'than',
#  'that',
#  'the',
#  'their',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'thing',
#  'things',
#  'third',
#  'this',
#  'those',
#  'though',
#  'thought',
#  'thousands',
#  'three',
#  'through',
#  'thus',
#  'time',
#  'tiny',
#  'to',
#  'today',
#  'together',
#  'told',
#  'too',
#  'took',
#  'toward',
#  'two',
#  'u',
#  'under',
#  'until',
#  'up',
#  'upon',
#  'us',
#  'use',
#  'used',
#  'v',
#  'very',
#  'w',
#  'warning',
#  'was',
#  'way',
#  'we',
#  'week',
#  'weeks',
#  'well',
#  'went',
#  'were',
#  'what',
#  'when',
#  'where',
#  'whether',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'whose',
#  'why',
#  'will',
#  'with',
#  'without',
#  'word',
#  'words',
#  'would',
#  'x',
#  'y',
#  'year',
#  'years',
#  'yet',
#  'you',
#  'your',
#  'z']

# %%
# Tokenize + Normalize with Stopping
def process_document(document_text):
    return ' '.join([token.lower() for token in document_text.split() if token.lower().isalnum() and token.lower() not in stopWordsDB])

# %%
processed_docs = [process_document(doc) for doc in docDB]
processed_docs
# Out:
# ['allies nassau december proposed help nato develop nuclear strike force europe attempt devise plan studied nassau accord president kennedy prime minister europeans saw emerging outlines nuclear nato wants support sprang crisis cancellation skybolt offer supply britain france polaris dec allied leader unreservedly welcomed polaris offer harold keeping separate nuclear deterrent britain saved neck prime minister beamed britain weapon generation terms britons sure government shoulder none development cost poured skybolt spend billion fleet submarines british able build prove nuclear fleet bomber force presumably obsolete tory backbenchers loudly skeptical call type nassau stipulates polaris submarine except supreme national interests committed truly multilateral nato force mean britain eventually strike force decide national interests justify withdrawal submarines particularly national interests conflict policy inclusion offer deliberate ploy jack kennedy end downgrade prized special relationship cartoonists farther supermac jumping de gaulle adenauer edith help developing force de quick crow vaunted ties humiliation bragged french skybolt fiasco vindicated decision develop bombs delivery systems charles de gaulle promised reflect polaris likelihood accept offer subject french force allied control de unswerving conviction russians invade western nation directly attacked meaning invite nuclear devastation helping allies unlike bomber pledged western strategic force de frappe responsible defense de gaulle argued atlantic alliance run efficiently triumvirate include france equal britain conditions british membership common market de gaulle suggested pointedly macmillan help britain share advanced missile technology france macmillan replied noncommittally discuss de gaulle guest hauteur france case ease entry europe grandeur konrad fearful de gaulle snap polaris offer achieve goal nato directorate government vowed 1954 manufacture nuclear adenauer increasingly apprehensive west germany relegated citizenship alliance official bulletin revived bitter cry pleas greater reliance conventional forces aimed raising german cannon fodder atomic knights frosty letter chancellor president kennedy suggested supplies 50 nato ground intend raise divisions conventional warfare strategic planners reason credible deterrent soviet attack strong army backed vast nuclear arsenal british french nuclear weapons independently russia inviting devastating soviet retaliation british french managed create nuclear capacity represents 4 nuclear power just damned state department official militarily except expected bail country throws pea russians else charles de gaulle hardly expected force de frappe becomes obsolete britain multilateral deterrent makes immediate polaris possible european minuteman answer spiraling cost diminishing value grandeur',
#  'russia charge 1954 nikita khrushchev launched grandiose virgin lands gamble plan plow 32 acres marginal land settle communist plant produce huge quantities desperately grain within scheme flopped pioneers tractor life bleak frontier except harvest lower previous worst virgin lands delivered half quotas khrushchev none blame fiasco scapegoat kazakhstan party boss nikolai fired errors dinmukhamed similarly bounced lapses work moscow purged former premier territory local central committee coincidence nikolai onetime khrushchev abruptly left post soviet deputy premier nine job farm expert ignatov misfortune boss special committee boost food production',
#  'berlin run hans weidner hoping escape drab east germany west odds cripple crutches lived village 115 southeast frontier freedom hans weidner major bus operated local communist regime ugly ancient chassis engine coughed coat paint disguise welts bruises decades chugging service bus ready junk pile weidner press service run sharp blades hazards great journey border weidner signed fellow jurgen wheel days pair feverish preparations garage weidner wagner attached heavy snowplow front plow scoop away heavy obstacles knew awaited roadblocks ahead lugs front wheel bolted sharp blades toughest affixed whirling edges chop barbed wire bits wedged sections steel plate inside bus stop bullets ready christmas weidner wagner piled wives children forgetting tons household belongings protection plotters shoveled ton coal potatoes bus chugged north berlin roads escape communist patrols just reached planned swing west order enter autobahn leading sector city en radiator froze subzero weather farther tire blew kids crying wives shivering cold panic arrived heavily guarded checkpoint autobahn berlin stop reconsider flying potatoes shrieked klaxons weidner thoughtfully installed advance communist guards obediently raised barriers bus doing emergency duty suddenly shooting late 40 crashing barrier 100 yards 20 yards away windshield passengers cargo coal potatoes corner old bus lurched stop road communists mattered foot inside west berlin']

# %%
# weight calc
def df(term, documentDB):
    return len([1 for document in documentDB if term in document.split()])

def idf(term, documentDB):
    return np.log10((len(documentDB) + 1) / (df(term, documentDB) + 0.5))

# %%
all_terms = sorted(set([term for doc in processed_docs for term in doc.split()]))
all_terms
# Out:
# ['100',
#  '115',
#  '1954',
#  '20',
#  '32',
#  '4',
#  '40',
#  '50',
#  'able',
#  'abruptly',
#  'accept',
#  'accord',
#  'achieve',
#  'acres',
#  'adenauer',
#  'advance',
#  'advanced',
#  'affixed',
#  'ahead',
#  'aimed',
#  'alliance',
#  'allied',
#  'allies',
#  'ancient',
#  'answer',
#  'apprehensive',
#  'argued',
#  'army',
#  'arrived',
#  'arsenal',
#  'atlantic',
#  'atomic',
#  'attached',
#  'attack',
#  'attacked',
#  'attempt',
#  'autobahn',
#  'awaited',
#  'away',
#  'backbenchers',
#  'backed',
#  'bail',
#  'barbed',
#  'barrier',
#  'barriers',
#  'beamed',
#  'becomes',
#  'belongings',
#  'berlin',
#  'billion',
#  'bits',
#  'bitter',
#  'blades',
#  'blame',
#  'bleak',
#  'blew',
#  'bolted',
#  'bomber',
#  'bombs',
#  'boost',
#  'border',
#  'boss',
#  'bounced',
#  'bragged',
#  'britain',
#  'british',
#  'britons',
#  'bruises',
#  'build',
#  'bulletin',
#  'bullets',
#  'bus',
#  'call',
#  'cancellation',
#  'cannon',
#  'capacity',
#  'cargo',
#  'cartoonists',
#  'case',
#  'central',
#  'chancellor',
#  'charge',
#  'charles',
#  'chassis',
#  'checkpoint',
#  'children',
#  'chop',
#  'christmas',
#  'chugged',
#  'chugging',
#  'citizenship',
#  'city',
#  'coal',
#  'coat',
#  'coincidence',
#  'cold',
#  'committed',
#  'committee',
#  'common',
#  'communist',
#  'communists',
#  'conditions',
#  'conflict',
#  'control',
#  'conventional',
#  'conviction',
#  'corner',
#  'cost',
#  'coughed',
#  'country',
#  'crashing',
#  'create',
#  'credible',
#  'cripple',
#  'crisis',
#  'crow',
#  'crutches',
#  'cry',
#  'crying',
#  'damned',
#  'days',
#  'de',
#  'dec',
#  'decades',
#  'december',
#  'decide',
#  'decision',
#  'defense',
#  'deliberate',
#  'delivered',
#  'delivery',
#  'department',
#  'deputy',
#  'desperately',
#  'deterrent',
#  'devastating',
#  'devastation',
#  'develop',
#  'developing',
#  'development',
#  'devise',
#  'diminishing',
#  'dinmukhamed',
#  'directly',
#  'directorate',
#  'discuss',
#  'disguise',
#  'divisions',
#  'doing',
#  'downgrade',
#  'drab',
#  'duty',
#  'ease',
#  'east',
#  'edges',
#  'edith',
#  'efficiently',
#  'else',
#  'emergency',
#  'emerging',
#  'en',
#  'end',
#  'engine',
#  'enter',
#  'entry',
#  'equal',
#  'errors',
#  'escape',
#  'europe',
#  'european',
#  'europeans',
#  'eventually',
#  'except',
#  'expected',
#  'expert',
#  'farm',
#  'farther',
#  'fearful',
#  'fellow',
#  'feverish',
#  'fiasco',
#  'fired',
#  'fleet',
#  'flopped',
#  'flying',
#  'fodder',
#  'food',
#  'foot',
#  'force',
#  'forces',
#  'forgetting',
#  'former',
#  'france',
#  'frappe',
#  'freedom',
#  'french',
#  'front',
#  'frontier',
#  'frosty',
#  'froze',
#  'gamble',
#  'garage',
#  'gaulle',
#  'generation',
#  'german',
#  'germany',
#  'goal',
#  'government',
#  'grain',
#  'grandeur',
#  'grandiose',
#  'great',
#  'greater',
#  'ground',
#  'guarded',
#  'guards',
#  'guest',
#  'half',
#  'hans',
#  'hardly',
#  'harold',
#  'harvest',
#  'hauteur',
#  'hazards',
#  'heavily',
#  'heavy',
#  'help',
#  'helping',
#  'hoping',
#  'household',
#  'huge',
#  'humiliation',
#  'ignatov',
#  'immediate',
#  'include',
#  'inclusion',
#  'increasingly',
#  'independently',
#  'inside',
#  'installed',
#  'intend',
#  'interests',
#  'invade',
#  'invite',
#  'inviting',
#  'jack',
#  'job',
#  'journey',
#  'jumping',
#  'junk',
#  'jurgen',
#  'just',
#  'justify',
#  'kazakhstan',
#  'keeping',
#  'kennedy',
#  'khrushchev',
#  'kids',
#  'klaxons',
#  'knew',
#  'knights',
#  'konrad',
#  'land',
#  'lands',
#  'lapses',
#  'late',
#  'launched',
#  'leader',
#  'leading',
#  'left',
#  'letter',
#  'life',
#  'likelihood',
#  'lived',
#  'local',
#  'loudly',
#  'lower',
#  'lugs',
#  'lurched',
#  'macmillan',
#  'major',
#  'makes',
#  'managed',
#  'manufacture',
#  'marginal',
#  'market',
#  'mattered',
#  'mean',
#  'meaning',
#  'membership',
#  'militarily',
#  'minister',
#  'minuteman',
#  'misfortune',
#  'missile',
#  'moscow',
#  'multilateral',
#  'nassau',
#  'nation',
#  'national',
#  'nato',
#  'neck',
#  'nikita',
#  'nikolai',
#  'nine',
#  'noncommittally',
#  'none',
#  'north',
#  'nuclear',
#  'obediently',
#  'obsolete',
#  'obstacles',
#  'odds',
#  'offer',
#  'official',
#  'old',
#  'onetime',
#  'operated',
#  'order',
#  'outlines',
#  'paint',
#  'pair',
#  'panic',
#  'particularly',
#  'party',
#  'passengers',
#  'patrols',
#  'pea',
#  'pile',
#  'piled',
#  'pioneers',
#  'plan',
#  'planned',
#  'planners',
#  'plant',
#  'plate',
#  'pleas',
#  'pledged',
#  'plotters',
#  'plow',
#  'ploy',
#  'pointedly',
#  'polaris',
#  'policy',
#  'possible',
#  'post',
#  'potatoes',
#  'poured',
#  'power',
#  'premier',
#  'preparations',
#  'president',
#  'press',
#  'presumably',
#  'previous',
#  'prime',
#  'prized',
#  'produce',
#  'production',
#  'promised',
#  'proposed',
#  'protection',
#  'prove',
#  'purged',
#  'quantities',
#  'quick',
#  'quotas',
#  'radiator',
#  'raise',
#  'raised',
#  'raising',
#  'reached',
#  'ready',
#  'reason',
#  'reconsider',
#  'reflect',
#  'regime',
#  'relationship',
#  'relegated',
#  'reliance',
#  'replied',
#  'represents',
#  'responsible',
#  'retaliation',
#  'revived',
#  'road',
#  'roadblocks',
#  'roads',
#  'run',
#  'russia',
#  'russians',
#  'saved',
#  'saw',
#  'scapegoat',
#  'scheme',
#  'scoop',
#  'sections',
#  'sector',
#  'separate',
#  'service',
#  'settle',
#  'share',
#  'sharp',
#  'shivering',
#  'shooting',
#  'shoulder',
#  'shoveled',
#  'shrieked',
#  'signed',
#  'similarly',
#  'skeptical',
#  'skybolt',
#  'snap',
#  'snowplow',
#  'southeast',
#  'soviet',
#  'special',
#  'spend',
#  'spiraling',
#  'sprang',
#  'state',
#  'steel',
#  'stipulates',
#  'stop',
#  'strategic',
#  'strike',
#  'strong',
#  'studied',
#  'subject',
#  'submarine',
#  'submarines',
#  'subzero',
#  'suddenly',
#  'suggested',
#  'supermac',
#  'supplies',
#  'supply',
#  'support',
#  'supreme',
#  'sure',
#  'swing',
#  'systems',
#  'technology',
#  'terms',
#  'territory',
#  'thoughtfully',
#  'throws',
#  'ties',
#  'tire',
#  'ton',
#  'tons',
#  'tory',
#  'toughest',
#  'tractor',
#  'triumvirate',
#  'truly',
#  'type',
#  'ugly',
#  'unlike',
#  'unreservedly',
#  'unswerving',
#  'value',
#  'vast',
#  'vaunted',
#  'village',
#  'vindicated',
#  'virgin',
#  'vowed',
#  'wagner',
#  'wants',
#  'warfare',
#  'weapon',
#  'weapons',
#  'weather',
#  'wedged',
#  'weidner',
#  'welcomed',
#  'welts',
#  'west',
#  'western',
#  'wheel',
#  'whirling',
#  'windshield',
#  'wire',
#  'withdrawal',
#  'within',
#  'wives',
#  'work',
#  'worst',
#  'yards']

# %%
idfCache = {term:idf(term, processed_docs) for term in all_terms}
idfCache
# Out:
# {'100': 0.4259687322722811,
#  '115': 0.4259687322722811,
#  '1954': 0.20411998265592482,
#  '20': 0.4259687322722811,
#  '32': 0.4259687322722811,
#  '4': 0.4259687322722811,
#  '40': 0.4259687322722811,
#  '50': 0.4259687322722811,
#  'able': 0.4259687322722811,
#  'abruptly': 0.4259687322722811,
#  'accept': 0.4259687322722811,
#  'accord': 0.4259687322722811,
#  'achieve': 0.4259687322722811,
#  'acres': 0.4259687322722811,
#  'adenauer': 0.4259687322722811,
#  'advance': 0.4259687322722811,
#  'advanced': 0.4259687322722811,
#  'affixed': 0.4259687322722811,
#  'ahead': 0.4259687322722811,
#  'aimed': 0.4259687322722811,
#  'alliance': 0.4259687322722811,
#  'allied': 0.4259687322722811,
#  'allies': 0.4259687322722811,
#  'ancient': 0.4259687322722811,
#  'answer': 0.4259687322722811,
#  'apprehensive': 0.4259687322722811,
#  'argued': 0.4259687322722811,
#  'army': 0.4259687322722811,
#  'arrived': 0.4259687322722811,
#  'arsenal': 0.4259687322722811,
#  'atlantic': 0.4259687322722811,
#  'atomic': 0.4259687322722811,
#  'attached': 0.4259687322722811,
#  'attack': 0.4259687322722811,
#  'attacked': 0.4259687322722811,
#  'attempt': 0.4259687322722811,
#  'autobahn': 0.4259687322722811,
#  'awaited': 0.4259687322722811,
#  'away': 0.4259687322722811,
#  'backbenchers': 0.4259687322722811,
#  'backed': 0.4259687322722811,
#  'bail': 0.4259687322722811,
#  'barbed': 0.4259687322722811,
#  'barrier': 0.4259687322722811,
#  'barriers': 0.4259687322722811,
#  'beamed': 0.4259687322722811,
#  'becomes': 0.4259687322722811,
#  'belongings': 0.4259687322722811,
#  'berlin': 0.4259687322722811,
#  'billion': 0.4259687322722811,
#  'bits': 0.4259687322722811,
#  'bitter': 0.4259687322722811,
#  'blades': 0.4259687322722811,
#  'blame': 0.4259687322722811,
#  'bleak': 0.4259687322722811,
#  'blew': 0.4259687322722811,
#  'bolted': 0.4259687322722811,
#  'bomber': 0.4259687322722811,
#  'bombs': 0.4259687322722811,
#  'boost': 0.4259687322722811,
#  'border': 0.4259687322722811,
#  'boss': 0.4259687322722811,
#  'bounced': 0.4259687322722811,
#  'bragged': 0.4259687322722811,
#  'britain': 0.4259687322722811,
#  'british': 0.4259687322722811,
#  'britons': 0.4259687322722811,
#  'bruises': 0.4259687322722811,
#  'build': 0.4259687322722811,
#  'bulletin': 0.4259687322722811,
#  'bullets': 0.4259687322722811,
#  'bus': 0.4259687322722811,
#  'call': 0.4259687322722811,
#  'cancellation': 0.4259687322722811,
#  'strong': 0.4259687322722811,
#  'studied': 0.4259687322722811,
#  'subject': 0.4259687322722811,
#  'submarine': 0.4259687322722811,
#  'submarines': 0.4259687322722811,
#  'subzero': 0.4259687322722811,
#  'suddenly': 0.4259687322722811,
#  'suggested': 0.4259687322722811,
#  'supermac': 0.4259687322722811,
#  'supplies': 0.4259687322722811,
#  'supply': 0.4259687322722811,
#  'support': 0.4259687322722811,
#  'supreme': 0.4259687322722811,
#  'sure': 0.4259687322722811,
#  'swing': 0.4259687322722811,
#  'systems': 0.4259687322722811,
#  'technology': 0.4259687322722811,
#  'terms': 0.4259687322722811,
#  'territory': 0.4259687322722811,
#  'thoughtfully': 0.4259687322722811,
#  'throws': 0.4259687322722811,
#  'ties': 0.4259687322722811,
#  'tire': 0.4259687322722811,
#  'ton': 0.4259687322722811,
#  'tons': 0.4259687322722811,
#  'tory': 0.4259687322722811,
#  'toughest': 0.4259687322722811,
#  'tractor': 0.4259687322722811,
#  'triumvirate': 0.4259687322722811,
#  'truly': 0.4259687322722811,
#  'type': 0.4259687322722811,
#  'ugly': 0.4259687322722811,
#  'unlike': 0.4259687322722811,
#  'unreservedly': 0.4259687322722811,
#  'unswerving': 0.4259687322722811,
#  'value': 0.4259687322722811,
#  'vast': 0.4259687322722811,
#  'vaunted': 0.4259687322722811,
#  'village': 0.4259687322722811,
#  'vindicated': 0.4259687322722811,
#  'virgin': 0.4259687322722811,
#  'vowed': 0.4259687322722811,
#  'wagner': 0.4259687322722811,
#  'wants': 0.4259687322722811,
#  'warfare': 0.4259687322722811,
#  'weapon': 0.4259687322722811,
#  'weapons': 0.4259687322722811,
#  'weather': 0.4259687322722811,
#  'wedged': 0.4259687322722811,
#  'weidner': 0.4259687322722811,
#  'welcomed': 0.4259687322722811,
#  'welts': 0.4259687322722811,
#  'west': 0.20411998265592482,
#  'western': 0.4259687322722811,
#  'wheel': 0.4259687322722811,
#  'whirling': 0.4259687322722811,
#  'windshield': 0.4259687322722811,
#  'wire': 0.4259687322722811,
#  'withdrawal': 0.4259687322722811,
#  'within': 0.4259687322722811,
#  'wives': 0.4259687322722811,
#  'work': 0.4259687322722811,
#  'worst': 0.4259687322722811,
#  'yards': 0.4259687322722811}

# %%
def calculateWeightVector(document, idfCache):
    counter = collections.Counter(document.split())
    return [counter.get(term, 0) * idfCache[term] for term in all_terms]

# %%
tdMatrix = pd.DataFrame([calculateWeightVector(document, idfCache) for docID, document in enumerate(processed_docs)], columns=all_terms)
tdMatrix
# Out:
#         100       115     1954        20        32         4        40  \
# 0  0.000000  0.000000  0.20412  0.000000  0.000000  0.425969  0.000000
# 1  0.000000  0.000000  0.20412  0.000000  0.425969  0.000000  0.000000
# 2  0.425969  0.425969  0.00000  0.425969  0.000000  0.000000  0.425969
#
#          50      able  abruptly  ...     wheel  whirling  windshield  \
# 0  0.425969  0.425969  0.000000  ...  0.000000  0.000000    0.000000
# 1  0.000000  0.000000  0.425969  ...  0.000000  0.000000    0.000000
# 2  0.000000  0.000000  0.000000  ...  0.851937  0.425969    0.425969
#
#        wire  withdrawal    within     wives      work     worst     yards
# 0  0.000000    0.425969  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.000000    0.000000  0.425969  0.000000  0.425969  0.425969  0.000000
# 2  0.425969    0.000000  0.000000  0.851937  0.000000  0.000000  0.851937
#
# [3 rows x 490 columns]

# %%
processed_queries = [process_document(query) for query in queriesDB]
processed_queries
# Out:
# ['allies nassau',
#  'khrushchev russia',
#  'berlin run hans weidner hoping escape drab east germany west']

# %%
def cosine_similarity(queryWeights, tdMatrix):
    return np.dot(tdMatrix, queryWeights) / (np.linalg.norm(queryWeights) * np.linalg.norm(tdMatrix, axis=1))

def find_similarity_order(query, tdMatrix):
    cosine_similarity_scores = cosine_similarity(calculateWeightVector(query, idfCache), tdMatrix.values)

    df = pd.DataFrame({'docID': tdMatrix.index, 'cosine_similarity_scores': cosine_similarity_scores})
    sorted_df = df.sort_values(by='cosine_similarity_scores', ascending=False)

    return sorted_df['docID'].values.tolist()

# %%
{str(query_no):find_similarity_order(query_text, tdMatrix) for query_no, query_text in enumerate(processed_queries)}
# Out:
# {'0': [0, 1, 2], '1': [1, 0, 2], '2': [2, 0, 1]}

# %% [markdown]
# BIM

# %%
def trk(term, rel_docs, non_rel_docs):
    rk = df(term, rel_docs)
    nrk = df(term, non_rel_docs)
    
    pk = (rk+0.5)/(len(rel_docs)-rk+0.5)
    qk = (nrk+0.5)/(len(non_rel_docs)-nrk+0.5)
    
    return np.log10(pk/qk)

# BIM Phase 1 with all non-rel docs.
trk_cache = {term:trk(term, {}, processed_docs) for term in all_terms}
trk_cache
# Out:
# {'100': 0.22184874961635637,
#  '115': 0.22184874961635637,
#  '1954': -0.22184874961635637,
#  '20': 0.22184874961635637,
#  '32': 0.22184874961635637,
#  '4': 0.22184874961635637,
#  '40': 0.22184874961635637,
#  '50': 0.22184874961635637,
#  'able': 0.22184874961635637,
#  'abruptly': 0.22184874961635637,
#  'accept': 0.22184874961635637,
#  'accord': 0.22184874961635637,
#  'achieve': 0.22184874961635637,
#  'acres': 0.22184874961635637,
#  'adenauer': 0.22184874961635637,
#  'advance': 0.22184874961635637,
#  'advanced': 0.22184874961635637,
#  'affixed': 0.22184874961635637,
#  'ahead': 0.22184874961635637,
#  'aimed': 0.22184874961635637,
#  'alliance': 0.22184874961635637,
#  'allied': 0.22184874961635637,
#  'allies': 0.22184874961635637,
#  'ancient': 0.22184874961635637,
#  'answer': 0.22184874961635637,
#  'apprehensive': 0.22184874961635637,
#  'argued': 0.22184874961635637,
#  'army': 0.22184874961635637,
#  'arrived': 0.22184874961635637,
#  'arsenal': 0.22184874961635637,
#  'atlantic': 0.22184874961635637,
#  'atomic': 0.22184874961635637,
#  'attached': 0.22184874961635637,
#  'attack': 0.22184874961635637,
#  'attacked': 0.22184874961635637,
#  'attempt': 0.22184874961635637,
#  'autobahn': 0.22184874961635637,
#  'awaited': 0.22184874961635637,
#  'away': 0.22184874961635637,
#  'backbenchers': 0.22184874961635637,
#  'western': 0.22184874961635637,
#  'wheel': 0.22184874961635637,
#  'whirling': 0.22184874961635637,
#  'windshield': 0.22184874961635637,
#  'wire': 0.22184874961635637,
#  'withdrawal': 0.22184874961635637,
#  'within': 0.22184874961635637,
#  'wives': 0.22184874961635637,
#  'work': 0.22184874961635637,
#  'worst': 0.22184874961635637,
#  'yards': 0.22184874961635637}

# %%
def calculateWeightVectorBIM(document, trk):
    token_stream = set(document.split())
    return [trk[term] if term in token_stream else 0 for term in all_terms]

def generate_td_matrix(processed_docs, trk_cache):
    return pd.DataFrame([calculateWeightVectorBIM(document, trk_cache) for document in processed_docs], columns=all_terms)

tdMatrixBIM = generate_td_matrix(processed_docs, trk_cache)
tdMatrixBIM
# Out:
#         100       115      1954        20        32         4        40  \
# 0  0.000000  0.000000 -0.221849  0.000000  0.000000  0.221849  0.000000
# 1  0.000000  0.000000 -0.221849  0.000000  0.221849  0.000000  0.000000
# 2  0.221849  0.221849  0.000000  0.221849  0.000000  0.000000  0.221849
#
#          50      able  abruptly  ...     wheel  whirling  windshield  \
# 0  0.221849  0.221849  0.000000  ...  0.000000  0.000000    0.000000
# 1  0.000000  0.000000  0.221849  ...  0.000000  0.000000    0.000000
# 2  0.000000  0.000000  0.000000  ...  0.221849  0.221849    0.221849
#
#        wire  withdrawal    within     wives      work     worst     yards
# 0  0.000000    0.221849  0.000000  0.000000  0.000000  0.000000  0.000000
# 1  0.000000    0.000000  0.221849  0.000000  0.221849  0.221849  0.000000
# 2  0.221849    0.000000  0.000000  0.221849  0.000000  0.000000  0.221849
#
# [3 rows x 490 columns]

# %%
def simple_similarity(tdMatrix, queryWeights):
    return np.dot(tdMatrix, queryWeights)

def find_similarity_order_BIM(query, tdMatrix):
    similarity_scores = simple_similarity(tdMatrix.values, calculateWeightVectorBIM(query, trk_cache))

    df = pd.DataFrame({"docID": tdMatrix.index, "similarity_scores": similarity_scores})
    sorted_df = df.sort_values(by="similarity_scores", ascending=False)

    return sorted_df['docID'].values.tolist()

# %%
BIM_phase_1_results = {str(query_no):find_similarity_order_BIM(query_text, tdMatrix) for query_no, query_text in enumerate(processed_queries)}
BIM_phase_1_results
# Out:
# {'0': [0, 1, 2], '1': [1, 2, 0], '2': [2, 1, 0]}

# %%
def recompute_trk(rel_docs, documentDB):
    relevant_docs, non_relevant_docs = {}, {}
    for docID, docText in enumerate(documentDB):
        if docID in rel_docs:
            relevant_docs[str(docID)] = docText
        else:
            non_relevant_docs[str(docID)] = docText
    return {term:trk(term, relevant_docs, non_relevant_docs) for term in all_terms}

def BIMPhase2(BIM_Phase_1_results, queries, docs):
    result = {}
    for qNo, qText in enumerate(queries):
        newTrk = recompute_trk(BIM_Phase_1_results[str(qNo)], docs)
        newTDMatrix = generate_td_matrix(processed_docs, newTrk)
        result[str(qNo)] = find_similarity_order_BIM(qText, newTDMatrix)
    return result

# %%
BIMPhase2(BIM_phase_1_results, processed_queries, processed_docs)
# Out:
# {'0': [1, 2, 0], '1': [0, 1, 2], '2': [0, 1, 2]}
