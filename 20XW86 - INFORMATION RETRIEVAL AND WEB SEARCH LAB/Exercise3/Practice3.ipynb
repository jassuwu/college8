# %%
import numpy as np
import pandas as pd
import re
from nltk.stem import PorterStemmer
import math
import collections

# %%
## Parsing
# Documents
with open('TIME.ALL', 'r') as f:
    text = f.read()
result = re.findall(r"\*TEXT\s+(\d{3})\s+(\d{2}/\d{2}(/|\s)\d{2})\s+PAGE\s+(\d{3})\n\n(.+?)(?=\*TEXT|$)", text, re.DOTALL)
docDB = {match[0]: {'id': match[0], 'date': match[1], 'page': int(match[3]), 'text': match[4]} for match in result}
docOnlyDB = {match[0]: match[4] for match in result}
docDF = pd.DataFrame(docDB).T

# Queries
with open('TIME.QUE', 'r') as f:
    text = f.read()
queryDB = re.findall(r'FIND\s+\d+\s+(.+?)(?=\n\n\*FIND\s+\d+\s+|$)', text, re.DOTALL)

# Stopwords
with open('TIME.STP','r') as f:
    text = f.read()
swDB = re.findall(r"^[A-Z]+$", text, re.MULTILINE)
swDB = set([word.lower() for word in swDB])

# Relevant docs
with open('TIME.REL', 'r') as f:
    text = f.read()
    lines = text.split("\n")
rdDB = {}
for line in lines:
    numbers = re.findall(r"\d+", line)
    if numbers:
        key = numbers[0]
        values = [int(n) for n in numbers[1:]]
        rdDB[key] = values

# %%
# Tokenize a document
def tokenizeDocument(documentText):
    return documentText.split()

# Normalize and Stop the token stream of a document
def normalizeAndStopTokenStream(tokenStream):
    return [token.lower() for token in tokenStream if token.lower().isalnum() and token.lower() not in swDB]

# Stem and the normalized token stream of a document
def stemNormalizedTokenStream(normalizedTokenStream):
    stemmer = PorterStemmer()
    return ' '.join([stemmer.stem(token) for token in normalizedTokenStream])

def processDocument(documentText):
    return stemNormalizedTokenStream(normalizeAndStopTokenStream(tokenizeDocument(documentText)))

# %%
processedDocDB = {docID: processDocument(text) for docID, text in docOnlyDB.items()}
processedDocDB
# Out:
# {'017': 'alli nassau decemb propos help nato develop nuclear strike forc europ attempt devis plan studi nassau accord presid kennedi prime minist european saw emerg outlin nuclear nato want support sprang crisi cancel skybolt offer suppli britain franc polari dec alli leader unreservedli welcom polari offer harold keep separ nuclear deterr britain save neck prime minist beam britain weapon gener term briton sure govern shoulder none develop cost pour skybolt spend billion fleet submarin british abl build prove nuclear fleet bomber forc presum obsolet tori backbench loudli skeptic call type nassau stipul polari submarin except suprem nation interest commit truli multilater nato forc mean britain eventu strike forc decid nation interest justifi withdraw submarin particularli nation interest conflict polici inclus offer deliber ploy jack kennedi end downgrad prize special relationship cartoonist farther supermac jump de gaull adenau edith help develop forc de quick crow vaunt tie humili brag french skybolt fiasco vindic decis develop bomb deliveri system charl de gaull promis reflect polari likelihood accept offer subject french forc alli control de unswerv convict russian invad western nation directli attack mean invit nuclear devast help alli unlik bomber pledg western strateg forc de frapp respons defens de gaull argu atlant allianc run effici triumvir includ franc equal britain condit british membership common market de gaull suggest pointedli macmillan help britain share advanc missil technolog franc macmillan repli noncommitt discuss de gaull guest hauteur franc case eas entri europ grandeur konrad fear de gaull snap polari offer achiev goal nato director govern vow 1954 manufactur nuclear adenau increasingli apprehens west germani releg citiz
#  '562': 'south korea fatigu flannel seoul deck festiv fineri south korea observ end militari dictatorship buse garland wreath newli flag decor storefront streetcar midnight curfew lift prison inmat releas amnesti drizzl nation capitol shiver spectat watch former militari strongman gener park chung oath offic south fifth civilian presid promis permit resurg dictatorship disguis park bright new republ dawn confus pessim creat new histori optim determin ring real chang south govern militari fatigu civilian flannel new presid dictatori parti garner 34 vote nation assembl opposit split parliamentari plural park plead nation opposit leader yun po bare lost presidenti boycot open dissid assemblymen threaten investig corrupt preval militari junta menac park south chaotic economi retail price climb 40 10 labor forc unemploy foreign exchang reserv plummet desper new dollop econom park invit congression deleg innaugur slash next total aid commit hope pressur park stabil economi continu dictatorship south korea palat dictatori park promis degre polit stabil',
#  '563': 'unit nation potent pygmi manhattan grew total 113 member admiss newli independ state zanzibar kenya zanzibar consist island indian total popul omaha zanzibar vote gener equal vote power nuclear giant soviet union'}

# %%
allTerms = sorted(list(set([token for doc in processedDocDB.values() for token in doc.split()])))
allTerms
# Out:
# ['00',
#  '1',
#  '10',
#  '100',
#  '100th',
#  '101',
#  '1013',
#  '103',
#  '104',
#  '105',
#  '108',
#  '109',
#  '10th',
#  '11',
#  '113',
#  '115',
#  '116',
#  '117',
#  '1170',
#  '119',
#  '12',
#  '120',
#  '125',
#  '126',
#  '128',
#  '12f',
#  '12in',
#  '13',
#  '130',
#  '131',
#  '133',
#  '136',
#  '137',
#  '138',
#  '139',
#  '13th',
#  '14',
#  '140',
#  '144',
#  '1498',
#  '14th',
#  '15',
#  '150',
#  '1512',
#  '155',
#  '156',
#  '158',
#  '159',
#  '15f',
#  '15member',
#  '15q6',
#  '15th',
#  '16',
#  '160',
#  '162',
#  '1630',
#  '165',
#  '166',
#  '16th',
#  '17',
#  '170',
#  '172',
#  '1735',
#  '1745',
#  '175',
#  '1750',
#  '1787',
#  '17th',
#  '18',
#  '180',
#  '1802',
#  '1805',
#  '182',
#  '1820',
#  '1825',
#  '1829',
#  '1830',
#  '1841',
#  '1848',
#  '185',
#  '1862',
#  '1864',
#  '1868',
#  '1872',
#  '1878',
#  '1887',
#  '1890',
#  '1894',
#  '1899',
#  '18th',
#  '19',
#  '190',
#  '1902',
#  '1904',
#  '1912',
#  '1916',
#  '1917',
#  '1919',
#  '1920',
#  '1921',
#  '1922',
#  '1924',
#  '1925',
#  '1926',
#  '1928',
#  '1929',
#  '1930',
#  '1931',
#  '1932',
#  '1933',
#  '1936',
#  '1937',
#  '1938',
#  '1939',
#  '194',
#  '1940',
#  '1941',
#  '1942',
#  '1943',
#  '1945',
#  '1946',
#  '1947',
#  '1948',
#  '1949',
#  '1950',
#  '1951',
#  '1952',
#  '1953',
#  '1954',
#  '1955',
#  '1956',
#  '1957',
#  '1958',
#  '1959',
#  '196',
#  '1960',
#  '1961',
#  '1962',
#  '1963',
#  '1964',
#  '1965',
#  '1967',
#  '1968',
#  '1969',
#  '1970',
#  '1972',
#  '1980',
#  '19th',
#  '1f',
#  '1st',
#  '2',
#  '20',
#  '200',
#  '202nd',
#  '206',
#  '20th',
#  '21',
#  '210',
#  '211',
#  '22',
#  '220',
#  '221',
#  '227',
#  '23',
#  '230',
#  '230o',
#  '24',
#  '243',
#  '244',
#  '24th',
#  '25',
#  '250',
#  '25th',
#  '26',
#  '260',
#  '267',
#  '27',
#  '270',
#  '274',
#  '28',
#  '29',
#  '294',
#  '2f',
#  '2fhour',
#  '2fi',
#  '2nd',
#  '3',
#  '30',
#  '300',
#  '300500',
#  '31',
#  '317th',
#  '32',
#  '325',
#  '33',
#  '330',
#  '333',
#  '33f',
#  '34',
#  '340',
#  '35',
#  '350',
#  '359',
#  '35f',
#  '35th',
#  '36',
#  '369',
#  '36th',
#  '37',
#  '370',
#  '37f',
#  '38',
#  '385',
#  '39',
#  '39th',
#  '3f',
#  '4',
#  '40',
#  '400',
#  '401',
#  '41',
#  '42',
#  '43',
#  '432',
#  '44',
#  '45',
#  '450',
#  '46',
#  '46th',
#  '47',
#  '48',
#  '480',
#  '485',
#  '49',
#  '4f',
#  '5',
#  '50',
#  '500',
#  '509',
#  '50minut',
#  '51',
#  '52',
#  '53',
#  '54',
#  '55',
#  '550',
#  '557th',
#  '56',
#  '561',
#  '562',
#  '57',
#  '57o',
#  '57th',
#  '582',
#  '59',
#  '596',
#  '5f',
#  '6',
#  '60',
#  '600',
#  '62',
#  '63',
#  '630',
#  '64',
#  '647',
#  '65',
#  '66',
#  '67',
#  '68',
#  '69',
#  '69th',
#  '6f',
#  '6th',
#  '7',
#  '70',
#  '700',
#  '707',
#  '70th',
#  '71',
#  '714',
#  '72',
#  '720',
#  '73',
#  '74',
#  '75',
#  '750',
#  '76',
#  '77',
#  '79',
#  '7f',
#  '7th',
#  '8',
#  '80',
#  '800',
#  '81',
#  '82',
#  '83',
#  '830mile',
#  '85',
#  '86',
#  '87',
#  '88',
#  '880',
#  '89',
#  '8f',
#  '8th',
#  '9',
#  '90',
#  '900',
#  '92',
#  '93',
#  '930',
#  '93rd',
#  '96',
#  '97',
#  '98',
#  '999',
#  'aachen',
#  'ababa',
#  'aback',
#  'abandon',
#  'abat',
#  'abb',
#  'abba',
#  'abbey',
#  'abd',
#  'abdel',
#  'abderrakim',
#  'abdic',
#  'abdin',
#  'abdirashid',
#  'abdul',
#  'abdullah',
#  'abdullahi',
#  'aberr',
#  'abid',
#  'abil',
#  'abingdon',
#  'abject',
#  'abl',
#  'ablaz',
#  'ablest',
#  'abli',
#  'aboard',
#  'abolish',
#  'abolit',
#  'abomin',
#  'aborigin',
#  'abort',
#  'abound',
#  'abraham',
#  'abras',
#  'abroad',
#  'abrupt',
#  'abruptli',
#  'abscess',
#  'absenc',
#  'absent',
#  'absentia',
#  'absolut',
#  'absolutist',
#  'absolv',
#  'absorb',
#  'absorbedli',
#  'absorpt',
#  'abstain',
#  'abstract',
#  'abstractionist',
#  'absurd',
#  'absurdli',
#  'abtal',
#  'abu',
#  'abubakar',
#  'abuild',
#  'abund',
#  'abus',
#  'abuzz',
#  'academ',
#  'academi',
#  'acced',
#  'acceler',
#  'accent',
#  'accept',
#  'access',
#  'accid',
#  'accident',
#  'acclaim',
#  'accommod',
#  'accompani',
#  'accompli',
#  'accomplic',
#  'accomplish',
#  'accord',
#  'accost',
#  'account',
#  'accra',
#  'accur',
#  'accuraci',
#  'accus',
#  'accustom',
#  'acerb',
#  'acheson',
#  'achiev',
#  'achil',
#  'acid',
#  'acidli',
#  'acknowledg',
#  'acquaint',
#  'acquir',
#  'acquit',
#  'acquitt',
#  'acr',
#  'acreag',
#  'acrid',
#  'acrimoni',
#  'act',
#  'action',
#  'activ',
#  'activist',
#  'actress',
#  'actual',
#  'acut',
#  'ad',
#  'adam',
#  'adamafio',
#  'adamantli',
#  'adapt',
#  'add',
#  'addi',
#  'addit',
#  'address',
#  'adelaid',
#  'aden',
#  'adenau',
#  'adept',
#  'adequ',
#  'adey',
#  'adher',
#  'adhiambo',
#  'adipos',
#  'adjac',
#  'adjoin',
#  'adjourn',
#  'adjust',
#  'adlai',
#  'adman',
#  'administ',
#  'administr',
#  'admir',
#  'admiralti',
#  'admiringli',
#  'admiss',
#  'admit',
#  'admittedli',
#  'admonit',
#  'adnan',
#  'adob',
#  'adolesc',
#  'adolf',
#  'adopt',
#  'adorn',
#  'adoula',
#  'adrian',
#  'adriat',
#  'adroit',
#  'adul',
#  'adult',
#  'adulter',
#  'adulteri',
#  'adulyadej',
#  'advanc',
#  'advantag',
#  'advent',
#  'adventur',
#  'advers',
#  'adversari',
#  'advertis',
#  'advic',
#  'advis',
#  'advisori',
#  'advoc',
#  'advocaci',
#  'adzhubei',
#  'aer',
#  'aerial',
#  'affabl',
#  'affair',
#  'affect',
#  'affection',
#  'affirm',
#  'affix',
#  'affluent',
#  'afford',
#  'affront',
#  'afghanistan',
#  'afir',
#  'aflak',
#  'afloat',
#  'afraid',
#  'africa',
#  'african',
#  'afrikaan',
#  'afsar',
#  'aftermath',
#  'afternoon',
#  'afterward',
#  'aga',
#  'age',
#  'agenc',
#  'agenda',
#  'agent',
#  'aggrav',
#  'aggress',
#  'aggressor',
#  'aghast',
#  'agincourt',
#  'agit',
#  'agon',
#  'agoni',
#  'agostinho',
#  'agrarian',
#  'agre',
#  'agreeabl',
#  'agreement',
#  'agreg',
#  'agricultur',
#  'agriculturalist',
#  'aground',
#  'agung',
#  'ahead',
#  'ahlan',
#  'ahm',
#  'ahmad',
#  'aicient',
#  'aid',
#  'aidmanship',
#  'ail',
#  'ailhous',
#  'ailment',
#  'aim',
#  'aimless',
#  'aimlessli',
#  'air',
#  'airbas',
#  'airborn',
#  'aircraft',
#  'airdrop',
#  'airfield',
#  'airi',
#  'airili',
#  'airlift',
#  'airlin',
#  'airmail',
#  'airman',
#  'airmen',
#  'airport',
#  'airpow',
#  'airspac',
#  'airspe',
#  'airstrip',
#  'airtight',
#  'airtrain',
#  'airway',
#  'aisl',
#  'aith',
#  'akbar',
#  'akintola',
#  'ako',
#  'akvavit',
#  'al',
#  'ala',
#  'alabama',
#  'alahu',
#  'alain',
#  'alam',
#  'alamein',
#  'alan',
#  'alarm',
#  'albania',
#  'albanian',
#  'albert',
#  'alberto',
#  'albion',
#  'alcohol',
#  'aldermaston',
#  'aldo',
#  'aldwych',
#  'alec',
#  'aleksandr',
#  'aleksei',
#  'aleppo',
#  'alert',
#  'alertli',
#  'alexand',
#  'alfi',
#  'alfon',
#  'alfr',
#  'algeri',
#  'algeria',
#  'algerian',
#  'algier',
#  'ali',
#  'alia',
#  'alibi',
#  'alic',
#  'alien',
#  'alight',
#  'align',
#  'alik',
#  'aliv',
#  'alkil',
#  'allah',
#  'allay',
#  'alleg',
#  'allegedli',
#  'allegi',
#  'allen',
#  'allencompass',
#  'alley',
#  'alleyway',
#  'alli',
#  'allianc',
#  'allnight',
#  'alloc',
#  'allot',
#  'allow',
#  'alltim',
#  'allweath',
#  'alma',
#  'almighti',
#  'almondey',
#  'aloft',
#  'alon',
#  'alongsid',
#  'aloof',
#  'aloud',
#  'aloy',
#  'aloysiu',
#  'alp',
#  'alphabet',
#  'alphons',
#  'alpin',
#  'alt',
#  'altai',
#  'alter',
#  'altern',
#  'altitud',
#  'altogeth',
#  'altstadt',
#  'alvi',
#  'alzett',
#  'amah',
#  'amalgam',
#  'amateur',
#  'amateurish',
#  'amaz',
#  'amazon',
#  'ambassador',
#  'ambatielo',
#  'amber',
#  'ambigu',
#  'ambit',
#  'ambiti',
#  'ambival',
#  'ambl',
#  'ambul',
#  'ambuscad',
#  'ambush',
#  'amen',
#  'amend',
#  'amer',
#  'america',
#  'american',
#  'amiabl',
#  'amic',
#  'amid',
#  'amidst',
#  'amin',
#  'amintor',
#  'amiti',
#  'amman',
#  'ammunit',
#  'amnesia',
#  'amnesti',
#  'amoeb',
#  'amorbach',
#  'amount',
#  'amour',
#  'ampl',
#  'ampli',
#  'amplifi',
#  'amrehn',
#  'amulet',
#  'amulre',
#  'amur',
#  'amus',
#  'anabasi',
#  'anachron',
#  'anachronist',
#  'analyst',
#  'analyz',
#  'anani',
#  'anarch',
#  'anarchi',
#  'anasta',
#  'anathema',
#  'anatoli',
#  'ancestor',
#  'ancestr',
#  'anchor',
#  'ancient',
#  'andersson',
#  'andr',
#  'andrea',
#  'andrei',
#  'andrew',
#  'andrian',
#  'aneurin',
#  'anew',
#  'angel',
#  'anger',
#  'angl',
#  'anglican',
#  'angloamerican',
#  'anglophil',
#  'anglophob',
#  'angola',
#  'angolan',
#  'angri',
#  'angrili',
#  'angst',
#  'angu',
#  'anguish',
#  'anhwei',
#  'anilin',
#  'anim',
#  'animist',
#  'animos',
#  'anita',
#  'ankara',
#  'ankl',
#  'ankledeep',
#  'ann',
#  'anna',
#  'annal',
#  'annapoli',
#  'annex',
#  'annihil',
#  'anniversari',
#  'annobon',
#  'announc',
#  'annoy',
#  'annual',
#  'anonym',
#  'answer',
#  'ant',
#  'antagon',
#  'antagonist',
#  'antechamb',
#  'antelop',
#  'antenna',
#  'anteroom',
#  'anthem',
#  'antholog',
#  'anthologist',
#  'anthoni',
#  'anthropologist',
#  'anti',
#  'antiafrican',
#  'antiaircraft',
#  'antibayar',
#  'antibuddhist',
#  'anticip',
#  'anticommunist',
#  'anticorrupt',
#  'antidiem',
#  'antigaul',
#  'antigovern',
#  'antigreek',
#  'antinass',
#  'antiparti',
#  'antiqu',
#  'antisabotag',
#  'antisept',
#  'antistrik',
#  'antitank',
#  'antithesi',
#  'antitreati',
#  'antoin',
#  'anton',
#  'antonin',
#  'antonio',
#  'anxieti',
#  'anxiou',
#  'anxious',
#  'anybodi',
#  'anyth',
#  'anyway',
#  'anywher',
#  'aodai',
#  'apart',
#  'apartheid',
#  'apathi',
#  'apbac',
#  'apc',
#  'apennin',
#  'apertura',
#  'apiec',
#  'aplenti',
#  'aplomb',
#  'apocryph',
#  'apollo',
#  'apolog',
#  'apologist',
#  'apoplect',
#  'appal',
#  'appar',
#  'apparatu',
#  'apparit',
#  'appeal',
#  'appear',
#  'appeas',
#  'appel',
#  'appetit',
#  'applaud',
#  'applaus',
#  'appli',
#  'applic',
#  'applier',
#  'appoint',
#  'apprais',
#  'appreci',
#  'apprehens',
#  'approach',
#  'appropri',
#  'approv',
#  'approxim',
#  'apr',
#  'april',
#  'apron',
#  'apt',
#  'arab',
#  'arabia',
#  'arabian',
#  'arabiya',
#  'arabl',
#  'ararat',
#  'araz',
#  'arbit',
#  'arbitr',
#  'arbuthnot',
#  'arc',
#  'archaic',
#  'archbishop',
#  'archduk',
#  'archer',
#  'archipelago',
#  'architect',
#  'archiv',
#  'arctic',
#  'arden',
#  'ardent',
#  'ardor',
#  'area',
#  'aref',
#  'arena',
#  'argoud',
#  'argoup',
#  'argu',
#  'argument',
#  'argyl',
#  'ari',
#  'arid',
#  'arieh',
#  'aris',
#  'aristocrat',
#  'arithmet',
#  'arku',
#  'arm',
#  'armada',
#  'armament',
#  'armband',
#  'armchair',
#  'arme',
#  'armenian',
#  'armi',
#  'arminia',
#  'armistic',
#  'armload',
#  'armor',
#  'armori',
#  'arnold',
#  'aros',
#  'arous',
#  'arra',
#  'arrang',
#  'array',
#  'arrest',
#  'arriv',
#  'arrog',
#  'arrow',
#  'ars',
#  'arsen',
#  'arson',
#  'art',
#  'arteri',
#  'arteriosclerosi',
#  'arthur',
#  'articl',
#  'articul',
#  'artifici',
#  'artilleri',
#  'artisan',
#  'artist',
#  'aruna',
#  'asaf',
#  'ascertain',
#  'ascet',
#  'asept',
#  'ash',
#  'ashley',
#  'ashor',
#  'ashtray',
#  'asia',
#  'asian',
#  'asiat',
#  'asid',
#  'ask',
#  'asleep',
#  'aso',
#  'aspect',
#  'aspers',
#  'asphalt',
#  'aspir',
#  'assadollah',
#  'assail',
#  'assassin',
#  'assault',
#  'assembl',
#  'assemblymen',
#  'assert',
#  'assessor',
#  'asset',
#  'assign',
#  'assist',
#  'associ',
#  'assort',
#  'assum',
#  'assumpt',
#  'assur',
#  'astir',
#  'astonish',
#  'astor',
#  'astound',
#  'astrakhan',
#  'astrolog',
#  'astronaut',
#  'asturia',
#  'astut',
#  'aswan',
#  'asylum',
#  'ata',
#  'atac',
#  'atami',
#  'atassi',
#  'ate',
#  'athen',
#  'athenian',
#  'athlet',
#  'atla',
#  'atlant',
#  'atmospher',
#  'atom',
#  'aton',
#  'atop',
#  'atqu',
#  'atrophi',
#  'attach',
#  'attack',
#  'attain',
#  'attassi',
#  'attempt',
#  'attend',
#  'attent',
#  'attila',
#  'attitud',
#  'attorney',
#  'attract',
#  'attribut',
#  'attun',
#  'auch',
#  'auction',
#  'audac',
#  'audaci',
#  'audienc',
#  'audrey',
#  'aug',
#  'auguri',
#  'august',
#  'augustu',
#  ...]

# %%
# No. of documents a term appears in the DB
def df(term, documentDB):
    return len([1 for document in documentDB if term in document])

# Inverse document frequency or informativeness of a term
def idf(term, documentDB):
    return math.log((len(documentDB) + 1) / (df(term, documentDB) + 0.5))

# Precalculating and making a cache
idfMap = {term:idf(term, processedDocDB.values()) for term in allTerms}
def getIDF(term):
    return idfMap[term]

# Calculate weights for a document
def calculateDocumentWeight(document):
    counter = collections.Counter(document.split())
    return [counter.get(term, 0) * getIDF(term) for term in allTerms]

# %%
tdMatrixDF = pd.DataFrame([calculateDocumentWeight(processedDoc) for processedDoc in processedDocDB.values()], columns=allTerms, index=processedDocDB.keys())

# %%
processedQueryDB = [processDocument(query) for query in queryDB]
processedQueryDB
# Out:
# ['kennedi administr pressur ngo dinh diem stop suppress buddhist',
#  'effort ambassador henri cabot lodg viet presid diem chang polici polit repress',
#  'number troop unit state station south viet nam compar number troop station west germani',
#  'polici new regim south viet nam overthrew presid diem',
#  'person involv viet nam coup',
#  'ceremoni suicid commit buddhist monk south viet nam seek gain act',
#  'reject princ norodom asian neutralist further aid nation',
#  'team survey public opinion north borneo sarawak join feder malaysia',
#  'opposit indonesia malaysia',
#  'grow controversi southeast asia propos creation feder malaysia',
#  'arrang indonesia administr west unit nation administr',
#  'controversi indonesia malaya propos feder unit territori',
#  'precari truce lao britain 14 nation agre truce geneva',
#  'form part name discuss intern relat east',
#  'elect park chung hee presid south korea',
#  'effort intern control commiss tri stop fight flare lao',
#  'withdraw sultan brunei propos feder malaysia',
#  'refus contribut fund support unit nation peacekeep forc',
#  'agreement unit arab republ saudi arabia withdraw forc involv observ unit nation expeditionari forc sent yemen',
#  'unit state warn limit unit nation payment level regular assess nation arrear fail pay issu involv arrear',
#  'secur council consider complaint 32 african nation south africa portug',
#  'altern offer forc withdrawn congo',
#  'countri newli join unit nation',
#  'unit nation effort portug free african coloni',
#  'consider conflict israel arab neighbor',
#  'effect major compris underdevelop nation',
#  'british propos new high level negoti russia summit meet',
#  'strength popular vote variou polit parti italian elect',
#  'talk secretari state rusk presid tito yugoslavia concern treatment yugoslav export unit state',
#  'parliamentari vote confid won prime minist macmillan profumo scandal effect profumo scandal chanc next british elect',
#  'leader figur discuss futur west german chancellorship',
#  'talk east germani premier khrushchev leader east european satellit countri',
#  'govern crisi produc controversi involv walloon fleme',
#  'difficulti minor govern face grow unrest agricultur polici',
#  'talk portug troubl portug african possess',
#  'czech regim head presid antonin novotni',
#  'wheat deal involv unit russia canada',
#  'specul number forc europ reduc',
#  'coalit govern form itali social christian democrat',
#  'result polit poll britain regard parti labor parti conserv',
#  'propos de gaull reject affect alli relat',
#  'presid de belief nuclear forc keyston european defens system',
#  'effort khrushchev closer relationship yugoslavia',
#  'opposit propos nonaggress pact',
#  'background new prime minist great britain',
#  'presid de polici british entri common market',
#  'propos unifi europ independ',
#  'propos',
#  'background new chancellor west ludwig erhard',
#  'meet minist pari april countri member nato seato',
#  'successor premier khrushchev',
#  'hint premier communist parti secretari retir post',
#  'premier khrushchev press nonaggress pact nato warsaw pact nation',
#  'communist reaction soviet sign nuclear test ban treati west',
#  'suggest presid kennedi nato nuclear missil fleet man intern crew',
#  'suggest presid kennedi soviet union cooper moon project',
#  'provis test ban treati',
#  'nation possess polari missil nuclear submarin fleet',
#  'disput soviet union inspect system geneva disarma confer',
#  'sign test ban treati',
#  'nation work nuclear weapon develop',
#  'support struggl autonomi',
#  'presid rule arab union present govern parti syria remain control',
#  'prime minist come attack motion entertain indian parliament govern offic',
#  'border disput israel syria',
#  'agreement syria iraq full econom uniti closer econom cooper',
#  'continu conflict india pakistan kashmir',
#  'indian fear communist chines invas',
#  'baath parti found michel gain control syria iraq aim unit arab countri',
#  'king sign away power state give free rein reform rule',
#  'somalia involv border disput neighbor militari aid suppli somalia russia',
#  'econom step south africa protest apartheid polici',
#  'increas critic premier ben bella algeria leader help bring algerian independ',
#  'mois tshomb katanga provinc congo',
#  'premier cyril order soviet embassi staff thrown countri spi charg',
#  'confer african uniti addi ababa 22 head state 31 independ african nation',
#  'relax control african territori',
#  'feder east africa form tanganyika uganda kenya gain independ dec 12 britain',
#  'algerian vote new constitut give full power premier ben polit parti',
#  'effect disput new nation africa asia area ferment latin america',
#  'communist chines trade soviet rest communist world',
#  'albanian back communist china ideolog split soviet union',
#  'red chines blame econom troubl withdraw russian technic assist seriou delay develop program']

# %%
def cosineSimiliary(queryWeights, tdMatrix):
    return np.dot(tdMatrix, queryWeights) / (np.linalg.norm(queryWeights) * np.linalg.norm(tdMatrix, axis=1))

def findTopNRelevantDocsWithCosineSimilarity(query, tdMatrixDF, N):
    # Calculate the cosine similarity
    cosineSimilarities = cosineSimiliary(calculateDocumentWeight(query), tdMatrixDF.values)

    # Sort in descending order of cosine similarity
    df = pd.DataFrame({'docID': tdMatrixDF.index, 'cosineSimilarity': cosineSimilarities})
    sorted_df = df.sort_values(by='cosineSimilarity', ascending=False)

    # Return the top 10 relevant documents from the sorted dataframe
    return sorted_df['docID'].values[:N].tolist()

# %%
cosineSimiliaryResults = {str(idx + 1):findTopNRelevantDocsWithCosineSimilarity(processedQuery, tdMatrixDF, 10) for idx, processedQuery in enumerate(processedQueryDB)}
cosineSimiliaryResults
# Out:
# {'1': ['396', '320', '414', '418', '498', '334', '390', '434', '464', '363'],
#  '2': ['498', '434', '418', '518', '464', '390', '414', '228', '269', '396'],
#  '3': ['060', '269', '405', '029', '464', '434', '470', '319', '021', '384'],
#  '4': ['434', '498', '269', '464', '228', '518', '418', '390', '396', '470'],
# Considering only one query here.

# %%
def trk(term, relevantDocsDB, nonRelevantDocsDB):
    rk = df(term, relevantDocsDB.values())
    nrk = df(term, nonRelevantDocsDB.values())
    Opk = (rk+0.5) / (len(relevantDocsDB.values())-rk+0.5)
    Oqk = (nrk+0.5) / (len(nonRelevantDocsDB.values())-nrk+0.5)
    return np.log10(Opk/Oqk)

# Phase 1 of BIM assumes all the documents to be non-relevant when computing the term score (t<sub>rk</sub>)
trkMap = {term:trk(term, {}, processedDocDB) for term in allTerms}

def getWeightVector(trk, document):
    tokenStream = set(document.split())
    return [trk[term] if term in tokenStream else 0 for term in allTerms]

def generateTDMDataFrame(trk, processedDocDB):
    return pd.DataFrame([getWeightVector(trk, processedDoc) for processedDoc in processedDocDB.values()], columns=allTerms, index=processedDocDB.keys())

# %%
def simpleSimiliaryForBIM(query, tdMatrix):
    queryWeights = getWeightVector(trkMap, query)
    return np.dot(tdMatrix, queryWeights)

def findTopNRelevantDocsWithBIM(query, tdMatrix, N):
    similarities = simpleSimiliaryForBIM(query, tdMatrix.values)
    
    df = pd.DataFrame({'docID': tdMatrix.index, 'similarity': similarities})
    sorted_df = df.sort_values(by='similarity', ascending=False)
    return sorted_df['docID'].values[:N].tolist()

# %%
def BIMPhase1(trk, queryDB, documentDB, N):
    tdMatrix = generateTDMDataFrame(trk, documentDB)
    return {str(queryID + 1):findTopNRelevantDocsWithBIM(query, tdMatrix, N) for queryID, query in enumerate(queryDB)}

# %%
BIMPhase1Top10 = BIMPhase1(trkMap, processedQueryDB, processedDocDB, 10)
BIMPhase1Top10
# Out:
# {'1': ['320', '464', '480', '163', '363', '533', '390', '334', '414', '396'],
#  '2': ['418', '434', '464', '414', '518', '498', '390', '112', '425', '128'],
#  '3': ['370', '405', '449', '319', '556', '464', '196', '200', '396', '029'],
#  '4': ['357', '087', '318', '418', '414', '434', '518', '269', '480', '498'],
#  '5': ['533', '418', '163', '252', '487', '449', '227', '396', '368', '152'],
#  '6': ['390', '415', '480', '334', '498', '418', '414', '396', '320', '533'],
#  '7': ['544', '081', '519', '546', '561', '204', '243', '485', '054', '227'],
#  '8': ['443', '479', '204', '335', '203', '270', '094', '389', '368', '265'],
#  '9': ['204', '443', '303', '479', '094', '335', '203', '256', '299', '389'],
#  '10': ['094', '204', '464', '203', '335', '396', '187', '123', '449', '443'],
#  '11': ['204', '071', '048', '256', '479', '203', '443', '303', '335', '094'],
#  '12': ['204', '094', '203', '335', '303', '479', '464', '256', '443', '243'],
#  '13': ['227', '361', '449', '300', '243', '545', '561', '226', '122', '040'],
#  '14': ['163', '370', '351', '088', '071', '480', '026', '346', '121', '260'],
#  '15': ['160', '176', '221', '562', '133', '370', '449', '223', '069', '217'],
#  '16': ['226', '300', '370', '345', '546', '045', '418', '561', '093', '122'],
#  '17': ['389', '094', '204', '203', '479', '303', '270', '060', '443', '335'],
#  '18': ['370', '477', '558', '071', '509', '123', '308', '190', '394', '158'],
#  '19': ['215', '253', '138', '163', '140', '333', '027', '459', '157', '121'],
#  '60': ['113', '392', '404', '380', '062', '436', '071', '117', '025', '463'],
#  '61': ['449', '017', '183', '341', '380', '404', '308', '540', '071', '356'],
#  '62': ['509', '449', '294', '498', '157', '156', '407', '252', '244', '267'],
#  '63': ['163', '140', '509', '398', '157', '215', '121', '252', '253', '138'],
#  '64': ['337', '413', '163', '424', '370', '085', '368', '356', '188', '543'],
#  '65': ['163', '446', '252', '350', '034', '161', '298', '307', '186', '215'],
#  '66': ['163', '268', '215', '140', '121', '252', '253', '157', '196', '509'],
#  '67': ['024', '096', '242', '461', '404', '550', '560', '025', '418', '204'],
#  '68': ['396', '365', '113', '054', '304', '541', '204', '024', '553', '394'],
#  '69': ['163', '509', '252', '522', '140', '187', '157', '215', '268', '295'],
#  '70': ['163', '066', '337', '552', '485', '162', '370', '449', '396', '408'],
#  '71': ['163', '159', '557', '449', '204', '280', '227', '252', '071', '368'],
#  '72': ['254', '110', '391', '442', '475', '427', '553', '204', '370', '163'],
#  '73': ['067', '267', '061', '411', '297', '071', '102', '225', '215', '187'],
#  '74': ['048', '462', '065', '021', '358', '028', '058', '238', '477', '100'],
#  '75': ['524', '418', '058', '190', '021', '498', '449', '434', '048', '059'],
#  '76': ['289', '286', '442', '297', '546', '477', '204', '335', '479', '303'],
#  '77': ['477', '322', '031', '460', '323', '219', '262', '493', '040', '145'],
#  '78': ['321', '546', '224', '163', '151', '322', '159', '198', '302', '149'],
#  '79': ['067', '187', '297', '071', '357', '061', '214', '252', '102', '267'],
#  '80': ['072', '365', '394', '071', '346', '351', '353', '449', '516', '274'],
#  '81': ['550', '050', '351', '203', '111', '396', '257', '422', '461', '335'],
#  '82': ['353', '394', '381', '449', '365', '351', '346', '364', '071', '404'],
#  '83': ['071', '204', '050', '337', '163', '434', '055', '324', '491', '370']}

# %%
def recomputeTrk(relDocs, documentDB):
    relevantDocs, nonRelevantDocs = {}, {}
    relDocSet = set(relDocs)
    for docID, text in documentDB.items():
        if docID in relDocSet:
            relevantDocs[docID] = text
        else:
            nonRelevantDocs[docID] = text
    return {term:trk(term, relevantDocs, nonRelevantDocs) for term in allTerms}

# %%
def BIMPhase2(BIMPhase1Result, queryDB, documentDB):
    BIMPhase2TopN = {}
    for queryID, query in enumerate(queryDB):
        queryRelDocsFromPhase1 = BIMPhase1Result[str(queryID+1)]
        trkAdjusted = recomputeTrk(queryRelDocsFromPhase1, documentDB)
        tdMatrixAdjusted = generateTDMDataFrame(trkAdjusted, documentDB)
        BIMPhase2TopN[str(queryID+1)] = findTopNRelevantDocsWithBIM(query, tdMatrixAdjusted, 10)
    return BIMPhase2TopN

# %%
BIMPhase2Top10 = BIMPhase2(BIMPhase1Top10, processedQueryDB[:5], processedDocDB)
BIMPhase2Top10
# Out:
# {'1': ['320', '480', '464', '390', '533', '363', '334', '498', '418', '434'],
#  '2': ['418', '434', '464', '414', '518', '498', '390', '425', '112', '516'],
#  '3': ['370', '449', '319', '556', '464', '200', '029', '405', '396', '163'],
#  '4': ['087', '357', '318', '414', '434', '418', '390', '320', '518', '519'],
#  '5': ['533', '163', '418', '487', '252', '449', '369', '368', '152', '396']}

# %%
# First 5 query results only because BIM takes 7 seconds per query 💀
givenRelDocs = dict(list(rdDB.items())[:5])

cosSimRelDocs = dict(list(cosineSimiliaryResults.items())[:5])
BIMRelDocs = BIMPhase2Top10

# %%
def metrics(predicted, actual):
    intersect = set(predicted) & set(actual)
    precision = len(intersect) / len(set(predicted))
    recall = len(intersect) / len(set(actual))
    f1 = 2 * precision * recall / (precision + recall) if precision + recall else 0
    return precision, recall, f1

cosSim_metrics = {q: metrics(cosSimRelDocs[q], givenRelDocs[q]) for q in givenRelDocs}
BIM_metrics = {q: metrics(BIMRelDocs[q], givenRelDocs[q]) for q in givenRelDocs}

metricDF = pd.concat([pd.DataFrame(m).T.assign(Algorithm=a) for m, a in [(cosSim_metrics, 'Cosine Similarity'), (BIM_metrics, 'BIM')]])
metricDF.columns = ['Precision', 'Recall', 'F1-Measure', 'Algorithm']
metricDF
# Out:
#    Precision  Recall  F1-Measure          Algorithm
# 1        0.0     0.0         0.0  Cosine Similarity
# 2        0.0     0.0         0.0  Cosine Similarity
# 3        0.0     0.0         0.0  Cosine Similarity
# 4        0.0     0.0         0.0  Cosine Similarity
# 5        0.0     0.0         0.0  Cosine Similarity
# 1        0.0     0.0         0.0                BIM
# 2        0.0     0.0         0.0                BIM
# 3        0.0     0.0         0.0                BIM
# 4        0.0     0.0         0.0                BIM
# 5        0.0     0.0         0.0                BIM

# %% [markdown]
# In conclusion, both algorithms _**suck**_.

# %% [markdown]
# ## Rocchio Relevance Feedback
#
# **What we have**: original queries, tdMatrix and cosine similarity results (for e.g.)
#
# **What we'll do**: recompute query weights with rocchio's forumla

# %%
def findBetterTopNWithRocchio(queryID, tdMatrix, cosine_similarity_results, N=10, alpha=1, beta=0.75, gamma=0.25):
    query = processedQueryDB[queryID]
    queryWeightVector = calculateDocumentWeight(query)

    all_docs = set(processedDocDB.keys())
    relevant_docs = cosine_similarity_results[str(queryID+1)]
    non_relevant_docs = list(all_docs - set(relevant_docs))

    relevant_centroid = np.mean(tdMatrix.loc[relevant_docs], axis=0)
    non_relevant_centroid = np.mean(tdMatrix.loc[non_relevant_docs], axis=0)

    recomputedQueryWeights = alpha * queryWeightVector + beta * relevant_centroid - gamma * non_relevant_centroid
    cosineSimilarities = cosineSimiliary(recomputedQueryWeights, tdMatrixDF.values)

    df = pd.DataFrame({'docID': tdMatrixDF.index, 'cosineSimilarity': cosineSimilarities})
    sorted_df = df.sort_values(by='cosineSimilarity', ascending=False)

    return sorted_df['docID'].values[:N].tolist()

# %%
rocchioRFResults = {queryID:findBetterTopNWithRocchio(queryID, tdMatrixDF, cosineSimiliaryResults) for queryID, _ in enumerate(processedQueryDB)}
rocchioRFResults
# Out:
# {0: ['418', '396', '320', '434', '414', '334', '390', '498', '464', '363'],
#  1: ['418', '434', '396', '498', '390', '464', '414', '320', '269', '334'],
