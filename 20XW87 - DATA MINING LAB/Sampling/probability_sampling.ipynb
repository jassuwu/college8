# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Random Sampling
#
# Used usually when there is no additional information.

# %%
N = 10000
mu = 10
std = 2

population_df = np.random.normal(mu, std, N)
population_df
# Out:
# array([ 9.84452338, 10.07946478,  9.80359981, ...,  9.1563559 ,
#         7.28179228,  9.18779374])

# %%
random_sample = np.random.choice(population_df, replace=False, size=1000)
random_sample
# Out:
# array([10.70474148,  7.49577188, 12.41617537, 11.20441524,  8.51939216,
#         8.52086256, 10.71391461, 10.42224103,  8.95798139,  8.09151738,
#        10.72325313, 10.89199926,  9.70283664,  8.69498958, 10.34229363,
#        10.31145463,  6.5631553 ,  8.68857315,  9.65800751,  9.83832444,
#        11.3135006 ,  8.23730776, 10.12740863,  7.50972246,  8.33034412,
#        10.96824758, 12.61809169,  9.65633059, 10.02783215,  9.03398906,
#        11.3533996 , 11.63327991, 15.22059193,  9.27619596, 10.97031855,
#         9.13220553, 12.96255815,  9.4066958 , 12.16513788, 10.97512912,
#         9.58640618,  5.26432105, 11.75206812, 10.74757652, 10.01916323,
#        12.96516019, 11.94191988, 13.30358753,  7.23348929,  8.64425093,
#        14.92253841, 11.11630208,  7.59950318, 15.16385975,  7.83830703,
#        11.60257951,  9.53479976,  8.83886605, 11.82705803,  8.01945542,
#         8.5802749 ,  9.94741653, 10.08125411,  9.53575005, 14.16081839,
#        10.61227982, 11.27820356, 11.22476231, 10.10822179, 10.69984066,
#        11.01915047, 10.3173141 ,  9.85842559,  9.39273188, 14.38715665,
#         9.63355711,  9.6685766 , 10.6882529 ,  9.26026826, 10.87801175,
#        10.81128105,  8.75318695, 13.04323128,  7.27813952,  8.85916419,
#        11.08788517, 12.70802509,  7.83244803,  9.8100427 , 10.86076661,
#        10.33589669, 11.20502518,  9.69452873,  9.79690249,  9.98367538,
#         7.25503788, 13.10502835,  8.80518537,  9.17878985, 11.34402954,
#        13.84314672,  8.63673261, 12.25236382,  9.79812485,  8.1493455 ,
#         8.62601343, 10.40009017,  8.51592544, 12.72516049,  7.01002781,
#         5.99024119, 12.89622131,  9.76613411,  9.86938691, 11.83706226,
#         8.71817021,  6.0989887 ,  9.36919758, 12.2935285 , 11.56650819,
#         8.49525102,  6.95224982, 11.37568581, 10.60852568,  8.54845366,
#        10.24857139, 11.27475162,  7.35279385,  8.47464074,  7.30057064,
#         8.46990212, 12.3566621 ,  9.17686675,  7.85596291,  7.72639391,
#         9.97438115, 10.53320752, 12.14858998,  8.98884348, 12.74501832,
#        11.51010975, 12.86424232,  8.63885415, 10.59382995, 15.21561438,
#         8.49020429, 11.9892482 , 10.44427086, 10.75756804,  6.83832686,
#         8.46779859,  9.81735588,  9.66863709, 12.21971259,  8.4629807 ,
#        13.80300279, 12.99509099,  8.85832269,  8.91823139,  9.40791132,
#        11.81620879, 13.35574294, 13.13677869,  8.45195085,  8.38261621,
#        10.59342081,  5.54208405,  8.41330757,  8.29865618, 11.31861017,
#        10.41905306,  8.34986713,  9.44037855, 10.37501207,  9.17462164,
#         9.37192349,  8.68777348, 10.03773892, 15.50105213, 15.31208187,
#         9.09201884, 11.23715348,  9.69762526,  6.79966113, 10.36873913,
#         8.28405051, 12.36736898,  5.25343804,  8.87827459,  9.41471817,
#        11.69035176, 10.21782824, 12.18986956,  7.23146008,  8.74902366,
#        10.01207038, 11.04152199,  7.56048924,  7.79071498,  8.7746137 ,
#        10.67652036, 12.14761345, 11.9266605 , 10.4611699 ,  9.82023816,
#         9.44130229,  9.86466787, 11.33233604, 12.88217231,  7.20098906,
#        10.22973855, 10.5375027 , 11.82978072,  9.47352182, 11.83958843,
#         7.81703683, 12.09310123, 12.80092304,  9.23921797,  9.17721698,
#         7.33159634, 11.66096614,  8.90561451, 13.95381346,  9.38142242])

# %% [markdown]
# # Systematic sampling
#
# Produces a random sample, but doesn't address the bias.

# %%
def systematic_sampling(df, step):
    id = pd.Series(np.arange(1, len(df), 1))
    df = pd.Series(df)
    df_pd = pd.concat([id, df], axis=1)
    df_pd.columns = ["id", "data"]

    selected_index = np.arange(1, len(df), step)

    return df_pd.iloc[selected_index]

sample_size = 10
step_size = N/sample_size
systematic_sample = systematic_sampling(population_df, step_size)
systematic_sample
# Out:
#           id       data
# 1        2.0  10.079465
# 1001  1002.0   9.757181
# 2001  2002.0   9.789676
# 3001  3002.0   8.475806
# 4001  4002.0   7.291114
# 5001  5002.0  11.902330
# 6001  6002.0  11.124445
# 7001  7002.0   9.244151
# 8001  8002.0   5.460468
# 9001  9002.0  10.819754

# %% [markdown]
# # Cluster Sampling
#
# Produces a random sample but does not address the bias in the sample.
#
# - Price: generated using Uniform distribution,
# - Id
# - event_type: which is a categorical variable with 3 possible values {type1, type2, type3}
# - click: binary variable taking values {0: no click, 1: click}

# %%
price_vb = pd.Series(np.random.uniform(1, 4, size=N))
id = pd.Series(np.arange(0, len(price_vb), 1))
event_type = pd.Series(np.random.choice(["type1", "type2", "type3"], size=len(price_vb)))
click = pd.Series(np.random.choice([0, 1], size=len(price_vb)))

df = pd.concat([id, price_vb, event_type, click], axis=1)
df.columns = ["id", "price", "event_type", "click"]
df
# Out:
#         id     price event_type  click
# 0        0  2.000831      type1      0
# 1        1  3.991851      type1      1
# 2        2  2.978841      type3      1
# 3        3  2.028109      type2      1
# 4        4  1.443728      type1      1
# ...    ...       ...        ...    ...
# 9995  9995  3.967940      type1      1
# 9996  9996  1.299092      type3      1
# 9997  9997  2.473600      type1      1
# 9998  9998  1.554249      type2      0
# 9999  9999  1.701928      type3      0
#
# [10000 rows x 4 columns]

# %%
def clustered_sampling(df, n_per_cluster, num_select_clusters):
    N = len(df)
    K = int(N/n_per_cluster)
    data = None

    for k in range(K):
        sample_k = df.sample(n_per_cluster)
        sample_k["cluster"] = np.repeat(k, len(sample_k))
        df = df.drop(index= sample_k.index)
        data = pd.concat([data, sample_k], axis=0)

    random_chosen_clusters = np.random.randint(0, K, size=num_select_clusters)
    return data[data.cluster.isin(random_chosen_clusters)]

clustered_sample = clustered_sampling(df, 100, 2)
clustered_sample
# Out:
#         id     price event_type  click  cluster
# 4018  4018  1.397140      type1      1       34
# 6568  6568  2.050874      type2      0       34
# 2768  2768  2.660684      type3      0       34
# 1980  1980  2.469532      type2      1       34
# 9893  9893  3.226760      type1      0       34
# ...    ...       ...        ...    ...      ...
# 8586  8586  1.361382      type2      0       67
# 8991  8991  3.009675      type1      0       67
# 6053  6053  1.808599      type3      1       67
# 5061  5061  2.039120      type3      1       67
# 8765  8765  1.109489      type1      1       67
#
# [200 rows x 5 columns]

# %% [markdown]
# # Weighted Sampling
#
# Produces a random and unbiased sample.

# %%
def weighted_sampling(df, n):
    def get_class_prob(x):
        weight_x = int(np.rint(n* len(x[x.click != 0])) / len(df[df.click != 0]))
        sampled_x = x.sample(weight_x).reset_index(drop=True)
        return sampled_x
    
    weighted_sample = df.groupby("event_type").apply(get_class_prob)
    print(weighted_sample["event_type"].value_counts())
    return weighted_sample

weighted_sample = weighted_sampling(df, 100)
weighted_sample
# Out:
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
#                  id     price event_type  click
# event_type
# type1      0    718  1.649533      type1      0
#            1   6544  3.421670      type1      0
#            2   3547  2.819380      type1      0
#            3   9041  2.719342      type1      1
#            4   4858  1.126370      type1      1
# ...             ...       ...        ...    ...
# type3      27  6728  2.655326      type3      0
#            28  9416  1.049936      type3      1
#            29  1264  3.809083      type3      1
#            30   139  2.107555      type3      1
#            31   891  2.566531      type3      0
#
# [99 rows x 4 columns]

# %% [markdown]
# # Stratified Sampling
#
# It's a way of combining clustered and weighted sampling.

# %%
def stratified_sampling(df, n, num_clusters_needed):
    N = len(df)
    num_obs_per_clusters = int(N/n)
    K = int(N/num_obs_per_clusters)
    
    stratas = None
    for k in range(K):
        weighted_sample_k = weighted_sampling(df, num_obs_per_clusters).reset_index(drop=True)
        weighted_sample_k["cluster"] = np.repeat(k, len(weighted_sample_k))
        stratas = pd.concat([stratas, weighted_sample_k], axis=0)
        df.drop(index=weighted_sample_k.index)

    selected_strata_clusters = np.random.randint(0, K, size=num_clusters_needed)
    return stratas[stratas.cluster.isin(selected_strata_clusters)]

stratified_sampling(df, 100, 2)
# Out:
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# event_type
# type1    34
# type2    33
# type3    32
# Name: count, dtype: int64
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
# /tmp/ipykernel_100984/569155858.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_sample = df.groupby("event_type").apply(get_class_prob)
#       id     price event_type  click  cluster
# 0   4771  2.264260      type1      1       19
# 1   8738  1.983886      type1      0       19
# 2   1635  3.071280      type1      0       19
# 3    683  1.673255      type1      0       19
# 4    176  3.792270      type1      1       19
# ..   ...       ...        ...    ...      ...
# 94  7662  3.240353      type3      1       65
# 95  8096  1.239540      type3      1       65
# 96  9325  3.085328      type3      1       65
# 97  1444  3.063573      type3      0       65
# 98  4405  2.706746      type3      1       65
#
# [198 rows x 5 columns]
