# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
from datetime import datetime

# %%
df = pd.read_csv('INFY.csv')
df
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 0    2014-03-01   7.588750   7.900000   6.615000   6.772500   5.254817
# 1    2014-04-01   6.863750   6.986250   6.363750   6.713750   5.209232
# 2    2014-05-01   6.697500   6.865000   6.257500   6.428750   4.988100
# 3    2014-06-01   6.460000   6.907500   6.380000   6.721250   5.215052
# 4    2014-07-01   6.702500   7.062500   6.583750   6.852500   5.387232
# ..          ...        ...        ...        ...        ...        ...
# 115  2023-10-01  17.030001  18.000000  16.209999  16.420000  16.208633
# 116  2023-11-01  16.299999  17.750000  16.270000  17.549999  17.549999
# 117  2023-12-01  17.469999  18.980000  17.290001  18.379999  18.379999
# 118  2024-01-01  18.240000  20.370001  17.549999  19.860001  19.860001
# 119  2024-02-01  19.860001  20.740000  19.680000  19.780001  19.780001
#
#         Volume
# 0    270594400
# 1    250525600
# 2    285789600
# 3    238680000
# 4    252547200
# ..         ...
# 115  177978500
# 116  118127400
# 117  121024700
# 118  203941000
# 119   87344700
#
# [120 rows x 7 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])
df
# Out:
#           Date       Open       High        Low      Close  Adj Close  \
# 0   2014-03-01   7.588750   7.900000   6.615000   6.772500   5.254817
# 1   2014-04-01   6.863750   6.986250   6.363750   6.713750   5.209232
# 2   2014-05-01   6.697500   6.865000   6.257500   6.428750   4.988100
# 3   2014-06-01   6.460000   6.907500   6.380000   6.721250   5.215052
# 4   2014-07-01   6.702500   7.062500   6.583750   6.852500   5.387232
# ..         ...        ...        ...        ...        ...        ...
# 115 2023-10-01  17.030001  18.000000  16.209999  16.420000  16.208633
# 116 2023-11-01  16.299999  17.750000  16.270000  17.549999  17.549999
# 117 2023-12-01  17.469999  18.980000  17.290001  18.379999  18.379999
# 118 2024-01-01  18.240000  20.370001  17.549999  19.860001  19.860001
# 119 2024-02-01  19.860001  20.740000  19.680000  19.780001  19.780001
#
#         Volume
# 0    270594400
# 1    250525600
# 2    285789600
# 3    238680000
# 4    252547200
# ..         ...
# 115  177978500
# 116  118127400
# 117  121024700
# 118  203941000
# 119   87344700
#
# [120 rows x 7 columns]

# %%
X, y = pd.DataFrame([time.mktime(d.timetuple()) for d in df['Date']]), df['Close']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
regr = LinearRegression()
 
regr.fit(X_train, y_train)
y_pred = regr.predict(X_test)

# %%
sns.lineplot(list(y_pred))
sns.lineplot(list(y_test))
# Out:
# <Axes: >

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
# Printout relevant metrics
print("Model Coefficients:", regr.coef_)
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
print("Coefficient of Determination:", r2_score(y_test, y_pred))
# Out:
# Model Coefficients: [4.73773427e-08]
# Mean Absolute Error: 2.616324441049892
# Coefficient of Determination: 0.6570952988723915
